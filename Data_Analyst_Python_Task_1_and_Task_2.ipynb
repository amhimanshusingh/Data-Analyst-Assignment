# %%
import pandas as pd

# %%
data = pd.read_csv('/content/dataset-1.csv')

# %%
data
# Out:
#      id_1  id_2  route   moto    car     rv   bus  truck
# 0     829   827      1   2.05   4.14   4.14  10.1   15.2
# 1     829   821      4   6.63  13.26  13.26  32.4   48.5
# 2     829   804      7  14.41  28.92  28.92  64.7   97.0
# 3     829   822      6   5.90  11.81  11.81  28.8   43.2
# 4     829   826      9   2.87   5.81   5.81  14.2   21.2
# ..    ...   ...    ...    ...    ...    ...   ...    ...
# 336   803   802      3   1.70   3.40   3.40   6.9   10.3
# 337   803   805      4   3.00   6.00   6.00  12.0   17.9
# 338   803   825      3  11.59  23.28  23.28  50.1   75.2
# 339   803   806      9   3.80   7.70   7.70  15.3   23.0
# 340   803   830      1  16.18  32.47  32.47  72.6  108.8
#
# [341 rows x 8 columns]

# %% [markdown]
# Question 1: Generate Car Matrix

# %%
import pandas as pd

def generate_car_matrix():
    # Read the dataset-1.csv into a DataFrame
    df = pd.read_csv('dataset-1.csv')

    # Create a pivot table with id_1 as index, id_2 as columns, and car as values
    car_matrix = df.pivot_table(index='id_1', columns='id_2', values='car', fill_value=0)

    # Set diagonal values to 0
    for i in car_matrix.index:
        car_matrix.at[i, i] = 0

    return car_matrix

# Example usage
result_matrix = generate_car_matrix()
print(result_matrix)
# Out:
# id_2    801    802    803    804    805    806    807    808    809    821  \
# id_1
# 801    0.00   2.80   6.00   7.70  11.70  13.40  16.90  19.60  21.00  23.52
# 802    2.80   0.00   3.40   5.20   9.20  10.90  14.30  17.10  18.50  20.92
# 803    6.00   3.40   0.00   2.00   6.00   7.70  11.10  13.90  15.30  17.72
# 804    7.70   5.20   2.00   0.00   4.40   6.10   9.50  12.30  13.70  16.12
# 805   11.70   9.20   6.00   4.40   0.00   2.00   5.40   8.20   9.60  12.02
# 806   13.40  10.90   7.70   6.10   2.00   0.00   3.80   6.60   8.00  10.42
# 807   16.90  14.30  11.10   9.50   5.40   3.80   0.00   2.90   4.30   6.82
# 808   19.60  17.10  13.90  12.30   8.20   6.60   2.90   0.00   1.70   4.12
# 809   21.00  18.50  15.30  13.70   9.60   8.00   4.30   1.70   0.00   2.92
# 821   23.52  20.92  17.72  16.12  12.02  10.42   6.82   4.12   2.92   0.00
# 822   24.67  22.07  18.87  17.27  13.17  11.57   7.97   5.27   4.07   1.80
# ...

# %% [markdown]
# Question 2: Car Type Count Calculation

# %%
import pandas as pd

def get_type_count(df):
    # Add a new categorical column 'car_type' based on the values of the 'car' column
    df['car_type'] = pd.cut(df['car'], bins=[float('-inf'), 15, 25, float('inf')],
                            labels=['low', 'medium', 'high'], right=False)

    # Calculate the count of occurrences for each car_type category
    type_count = df['car_type'].value_counts().to_dict()

    # Sort the dictionary alphabetically based on keys
    type_count = dict(sorted(type_count.items()))

    return type_count

# Example usage
df = pd.read_csv('dataset-1.csv')
result_type_count = get_type_count(df)
print(result_type_count)
# Out:
# {'high': 56, 'low': 196, 'medium': 89}

# %% [markdown]
# Question 3: Bus Count Index Retrieval

# %%
import pandas as pd

def get_bus_indexes(df: pd.DataFrame) -> list:
    """
    Returns the indexes where the 'bus' values are greater than twice the mean.

    Args:
        df (pandas.DataFrame): Input DataFrame.

    Returns:
        list: List of indexes where 'bus' values exceed twice the mean.
    """
    # Calculate the mean value of the 'bus' column
    bus_mean = df['bus'].mean()

    # Identify indexes where 'bus' values are greater than twice the mean
    bus_indexes = df[df['bus'] > 2 * bus_mean].index.tolist()

    # Sort the list in ascending order
    bus_indexes.sort()

    return bus_indexes

# Example usage:
# Assuming df is the DataFrame read from 'dataset-1.csv'
# bus_indexes_result = get_bus_indexes(df)

# %% [markdown]
# ### Question 4 Route Filtering

# %%
import pandas as pd

def filter_routes(df: pd.DataFrame) -> list:
    """
    Filters and returns routes with average 'truck' values greater than 7.

    Args:
        df (pandas.DataFrame): Input DataFrame.

    Returns:
        list: List of route names with average 'truck' values greater than 7.
    """
    # Group by 'route' and calculate the average 'truck' values
    route_avg_truck = df.groupby('route')['truck'].mean()

    # Filter routes where the average 'truck' values are greater than 7
    selected_routes = route_avg_truck[route_avg_truck > 7].index.tolist()

    # Sort the list of routes in ascending order
    selected_routes.sort()

    return selected_routes

# Example usage:
# Assuming df is the DataFrame read from 'dataset-1.csv'
# filtered_routes_result = filter_routes(df)

# %% [markdown]
# ### Question 5: Matrix Value Modification

# %%
import pandas as pd

def multiply_matrix(input_matrix):
    # Create a copy of the input DataFrame to avoid modifying the original DataFrame
    modified_matrix = input_matrix.copy()

    # Apply the specified logic to modify values in the DataFrame
    modified_matrix[modified_matrix > 20] *= 0.75
    modified_matrix[modified_matrix <= 20] *= 1.25

    # Round the values to 1 decimal place
    modified_matrix = modified_matrix.round(1)

    return modified_matrix

# Example usage
# Assuming result_matrix is the DataFrame obtained from Question 1
result_matrix_modified = multiply_matrix(result_matrix)
print(result_matrix_modified)
# Out:
# id_2   801   802   803   804   805   806   807   808   809   821   822   823  \
# id_1
# 801    0.0   3.5   7.5   9.6  14.6  16.8  21.1  24.5  19.7  22.0  23.1  24.9
# 802    3.5   0.0   4.2   6.5  11.5  13.6  17.9  21.4  23.1  19.6  20.7  22.4
# 803    7.5   4.2   0.0   2.5   7.5   9.6  13.9  17.4  19.1  22.2  23.6  19.4
# 804    9.6   6.5   2.5   0.0   5.5   7.6  11.9  15.4  17.1  20.2  21.6  23.9
# 805   14.6  11.5   7.5   5.5   0.0   2.5   6.8  10.2  12.0  15.0  16.5  18.8
# 806   16.8  13.6   9.6   7.6   2.5   0.0   4.8   8.2  10.0  13.0  14.5  16.8
# 807   21.1  17.9  13.9  11.9   6.8   4.8   0.0   3.6   5.4   8.5  10.0  12.3
# 808   24.5  21.4  17.4  15.4  10.2   8.2   3.6   0.0   2.1   5.2   6.6   8.9
# 809   19.7  23.1  19.1  17.1  12.0  10.0   5.4   2.1   0.0   3.6   5.1   7.4
# 821   22.0  19.6  22.2  20.2  15.0  13.0   8.5   5.2   3.6   0.0   2.2   4.6
# 822   23.1  20.7  23.6  21.6  16.5  14.5  10.0   6.6   5.1   2.2   0.0   2.8
# ...

# %%
data2 = pd.read_csv('/content/dataset-2.csv')

# %%
data2
# Out:
#             id        name     id_2  startDay startTime     endDay   endTime  \
# 0      1040000  Montgomery       -1    Monday  05:00:00  Wednesday  10:00:00
# 1      1040010       Black       -1    Monday  10:00:00     Friday  15:00:00
# 2      1040020     Emerald       -1  Thursday  15:00:00     Friday  19:00:00
# 3      1040030       Foley       -1    Monday  19:00:00     Friday  23:59:59
# 4      1050000    Whittier  1050001  Saturday  00:00:00     Sunday  23:59:59
# ...        ...         ...      ...       ...       ...        ...       ...
# 39509  1031012     Baldwin  1031030    Monday  19:00:00     Friday  23:59:59
# 39510  1031012     Baldwin  1031032  Saturday  00:00:00     Sunday  23:59:59
# 39511  1031014    Thickson  1031016  Saturday  00:00:00     Sunday  23:59:59
# 39512  1031014    Thickson  1031018    Monday  05:00:00  Wednesday  10:00:00
# 39513  1031014    Thickson  1031020    Monday  10:00:00     Friday  15:00:00
#
# ...

# %% [markdown]
# ### Question 6: Time Check

# %%
import pandas as pd

def check_timestamp_completeness(df):
    # Combine date and time columns to create a datetime column
    df['start_datetime'] = pd.to_datetime(df['startDay'] + ' ' + df['startTime'])
    df['end_datetime'] = pd.to_datetime(df['endDay'] + ' ' + df['endTime'])

    # Check if timestamps cover a full 24-hour period
    hour_range_check = ((df['start_datetime'].dt.hour.min() == 0) and
                        (df['end_datetime'].dt.hour.max() == 23))

    # Check if timestamps span all 7 days of the week
    day_of_week_check = df['start_datetime'].dt.dayofweek.nunique() == 7

    # Group by (id, id_2) and check completeness for each group
    completeness_check = df.groupby(['id', 'id_2']).apply(lambda group: hour_range_check and day_of_week_check).astype(bool)

    return completeness_check

# Example usage
# Adjust the file path accordingly
df = pd.read_csv('dataset-2.csv')
result_series = check_timestamp_completeness(df)
print(result_series)

# %% [markdown]
# ### Python Task 2

# %%
data3 = pd.read_csv('/content/dataset-3.csv')

# %%
data3
# Out:
#     id_start   id_end  distance
# 0    1001400  1001402       9.7
# 1    1001402  1001404      20.2
# 2    1001404  1001406      16.0
# 3    1001406  1001408      21.7
# 4    1001408  1001410      11.1
# 5    1001410  1001412      15.6
# 6    1001412  1001414      18.2
# 7    1001414  1001416      13.2
# 8    1001416  1001418      13.6
# 9    1001418  1001420      12.9
# 10   1001420  1001422       9.6
# 11   1001422  1001424      11.4
# 12   1001424  1001426      18.6
# 13   1001426  1001428      15.8
# 14   1001428  1001430       8.6
# 15   1001430  1001432       9.0
# 16   1001432  1001434       7.9
# 17   1001434  1001436       4.0
# 18   1001436  1001438       9.0
# 19   1001436  1001437       5.0
# 20   1001438  1001437       4.0
# 21   1001438  1001440      10.0
# 22   1001440  1001442       3.9
# 23   1001442  1001488       4.5
# 24   1001488  1004356       4.0
# 25   1004356  1004354       2.0
# 26   1004354  1004355       2.0
# 27   1004355  1001444       0.7
# ...

# %% [markdown]
# ## Question 1: Distance Matrix Calculation

# %%
import pandas as pd

def calculate_distance_matrix('/content/dataset-3.csv'):
    # Read the dataset-3.csv into a DataFrame
    df = pd.read_csv('/content/dataset-3.csv')

    # Create a DataFrame with IDs as index and columns
    distance_matrix = pd.pivot_table(df, values='Distance', index='ID1', columns='ID2', aggfunc='sum', fill_value=0)

    # Ensure the matrix is symmetric
    distance_matrix = distance_matrix + distance_matrix.T

    # Set diagonal values to 0
    distance_matrix.values[[range(distance_matrix.shape[0])]*2] = 0

    return distance_matrix

# Example usage
# Adjust the file path accordingly
distance_matrix = calculate_distance_matrix('dataset-3.csv')
print(distance_matrix)
# Out:
#   File "<ipython-input-51-9dba4a8c767e>", line 3
#     def calculate_distance_matrix('/content/dataset-3.csv'):
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Question 2: Unroll Distance Matrix

# %%
import pandas as pd

def unroll_distance_matrix(distance_matrix):
    # Reset the index to have 'ID1' and 'ID2' as columns
    distance_matrix_reset = distance_matrix.reset_index()

    # Melt the DataFrame to convert it to long format
    melted_df = pd.melt(distance_matrix_reset, id_vars='ID1', var_name='ID2', value_name='distance')

    # Exclude rows where id_start is equal to id_end
    unrolled_df = melted_df[melted_df['ID1'] != melted_df['ID2']].reset_index(drop=True)

    return unrolled_df

# Example usage
# Assuming distance_matrix is the DataFrame obtained from Question 1
# Adjust the DataFrame name based on your actual DataFrame
unrolled_distance_df = unroll_distance_matrix(distance_matrix)
print(unrolled_distance_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-219381a3ac71> in <cell line: 18>()
#      16 # Assuming distance_matrix is the DataFrame obtained from Question 1
#      17 # Adjust the DataFrame name based on your actual DataFrame
# ---> 18 unrolled_distance_df = unroll_distance_matrix(distance_matrix)
#      19 print(unrolled_distance_df)
#
# NameError: name 'distance_matrix' is not defined

# %% [markdown]
# Question 3: Finding IDs within Percentage Threshold

# %%
import pandas as pd

def find_ids_within_ten_percentage_threshold(df, reference_value):
    # Filter the DataFrame based on the reference value
    reference_df = df[df['id_start'] == reference_value]

    # Calculate the average distance for the reference value
    reference_avg_distance = reference_df['distance'].mean()

    # Calculate the threshold values
    lower_threshold = reference_avg_distance * 0.9
    upper_threshold = reference_avg_distance * 1.1

    # Filter the DataFrame based on the threshold values
    filtered_df = df[(df['distance'] >= lower_threshold) & (df['distance'] <= upper_threshold)]

    # Get the unique values from the 'id_start' column and sort them
    result_ids = sorted(filtered_df['id_start'].unique())

    return result_ids

# Example usage
# Assuming unrolled_distance_df is the DataFrame obtained from the previous question
# Adjust the DataFrame name based on your actual DataFrame
reference_value = 123  # Replace with the desired reference value
result_ids = find_ids_within_ten_percentage_threshold(unrolled_distance_df, reference_value)
print(result_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-1c540fc602ec> in <cell line: 26>()
#      24 # Adjust the DataFrame name based on your actual DataFrame
#      25 reference_value = 123  # Replace with the desired reference value
# ---> 26 result_ids = find_ids_within_ten_percentage_threshold(unrolled_distance_df, reference_value)
#      27 print(result_ids)
#
# NameError: name 'unrolled_distance_df' is not defined

# %% [markdown]
# ### Question 4: Calculate Toll Rate

# %%
import pandas as pd

def calculate_toll_rate(df):
    # Define rate coefficients for each vehicle type
    rate_coefficients = {'moto': 0.8, 'car': 1.2, 'rv': 1.5, 'bus': 2.2, 'truck': 3.6}

    # Create new columns for each vehicle type
    for vehicle_type, rate_coefficient in rate_coefficients.items():
        df[vehicle_type] = df['distance'] * rate_coefficient

    return df

# Example usage
# Assuming unrolled_distance_df is the DataFrame obtained from the previous question
# Adjust the DataFrame name based on your actual DataFrame
result_df = calculate_toll_rate(unrolled_distance_df)
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-540cc403fbfc> in <cell line: 16>()
#      14 # Assuming unrolled_distance_df is the DataFrame obtained from the previous question
#      15 # Adjust the DataFrame name based on your actual DataFrame
# ---> 16 result_df = calculate_toll_rate(unrolled_distance_df)
#      17 print(result_df)
#
# NameError: name 'unrolled_distance_df' is not defined

# %% [markdown]
# Question 5: Calculate Time-Based Toll Rates

# %%
import pandas as pd
from datetime import time

def calculate_time_based_toll_rates(df):
    # Define time ranges and discount factors
    time_ranges = [(time(0, 0, 0), time(10, 0, 0)),
                   (time(10, 0, 1), time(18, 0, 0)),
                   (time(18, 0, 1), time(23, 59, 59))]

    discount_factors_weekdays = [0.8, 1.2, 0.8]
    discount_factor_weekends = 0.7

    # Create new columns for start_day, start_time, end_day, and end_time
    df['start_day'] = df['start_datetime'].dt.day_name()
    df['start_time'] = df['start_datetime'].dt.time
    df['end_day'] = df['end_datetime'].dt.day_name()
    df['end_time'] = df['end_datetime'].dt.time

    # Apply discount factors based on time ranges
    for time_range, discount_factor in zip(time_ranges, discount_factors_weekdays):
        mask = (df['start_time'] >= time_range[0]) & (df['start_time'] <= time_range[1])
        df.loc[mask, ['moto', 'car', 'rv', 'bus', 'truck']] *= discount_factor

    # Apply constant discount factor for weekends
    weekend_mask = (df['start_datetime'].dt.dayofweek >= 5)  # 5 and 6 represent Saturday and Sunday
    df.loc[weekend_mask, ['moto', 'car', 'rv', 'bus', 'truck']] *= discount_factor_weekends

    return df

# Example usage
# Assuming result_df is the DataFrame obtained from Question 4
# Adjust the DataFrame name based on your actual DataFrame
result_with_time_based_tolls = calculate_time_based_toll_rates(result_df)
print(result_with_time_based_tolls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-cb64ad4cd4ad> in <cell line: 33>()
#      31 # Assuming result_df is the DataFrame obtained from Question 4
#      32 # Adjust the DataFrame name based on your actual DataFrame
# ---> 33 result_with_time_based_tolls = calculate_time_based_toll_rates(result_df)
#      34 print(result_with_time_based_tolls)
#
# NameError: name 'result_df' is not defined
